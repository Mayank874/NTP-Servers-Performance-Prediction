# %%
#Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#Importing the dataset 
dataset = pd.read_csv('GPS Data _NTP.csv')

# %%
#Creating data frames
x = dataset.iloc[:,0:1].values
y = dataset.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 1/3, random_state = 0)

from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression()
linear_regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Predicting the Test Set Results
y_pred = linear_regressor.predict(x_test)

# %%
#Visualizing the training set results
plt.scatter(x_train, y_train, color = 'red')
plt.plot(x_train, linear_regressor.predict(x_train), color = 'blue')
plt.title('NTP Servers Performance (Training Set)')
plt.xlabel('Serial No. of NTP Servers: - ')
plt.ylabel('192.168.251.33 with GPS')
plt.show()

# %%
#Visualizing the Test Set Results
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_test, linear_regressor.predict(x_test), color = 'blue')
plt.title('Visualization of Test Data')
plt.xlabel('Serial No. of NTP Servers: - ')
plt.ylabel('192.168.251.33 with GPS')
plt.show()

# %%
#Performance Evaluation

#Importing metrics Library
from sklearn import metrics
#Evaluating the model and printing the results using MAE
print("Mean Absolute Error is: - ", metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error is: -  0.0010522628549159653

# %%
#Evaluating the model and printing the results using MSE
print("Mean Squared Error is: - ", metrics.mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error is: -  2.4912082301572148e-06

# %%
#Importing the math library
import math

#Evaluating the model and printing the results using RMSE
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 0.0015783561797506971
